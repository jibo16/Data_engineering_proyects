# %%
import os
from twilio.rest import Client
from twilio_config import TWILIO_ACCOUNT_SID, TWILIO_AUTH_TOKEN, PHONE_NUMBER, API_KEY_WAPI, P_PHONE
import time

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import requests
from tqdm import tqdm
import numpy as np

# %%
request_url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY_WAPI}&q=mexico city&days=1&aqi=no&alerts=no"

# %%
response = requests.get(request_url).json()
response
# Out:
# {'location': {'name': 'Mexico City',
#   'region': 'The Federal District',
#   'country': 'Mexico',
#   'lat': 19.43,
#   'lon': -99.13,
#   'tz_id': 'America/Mexico_City',
#   'localtime_epoch': 1701110702,
#   'localtime': '2023-11-27 12:45'},
#  'current': {'last_updated_epoch': 1701110700,
#   'last_updated': '2023-11-27 12:45',
#   'temp_c': 17.0,
#   'temp_f': 62.6,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 6.9,
#   'wind_kph': 11.2,
#   'wind_degree': 100,
#   'wind_dir': 'E',
#   'pressure_mb': 1029.0,
#   'pressure_in': 30.39,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 59,
#   'cloud': 100,
#   'feelslike_c': 17.0,
#   'feelslike_f': 62.6,
#   'vis_km': 8.0,
#   'vis_miles': 4.0,
#   'uv': 4.0,
#   'gust_mph': 3.6,
#   'gust_kph': 5.8},
#  'forecast': {'forecastday': [{'date': '2023-11-27',
#     'date_epoch': 1701043200,
#     'day': {'maxtemp_c': 21.5,
#      'maxtemp_f': 70.7,
#      'mintemp_c': 12.5,
#      'mintemp_f': 54.5,
#      'avgtemp_c': 15.9,
#      'avgtemp_f': 60.6,
#      'maxwind_mph': 7.2,
#      'maxwind_kph': 11.5,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.8,
#      'avgvis_miles': 6.0,
#      'avghumidity': 73.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'uv': 4.0},
#     'astro': {'sunrise': '06:52 AM',
#      'sunset': '05:57 PM',
#      'moonrise': '06:15 PM',
#      'moonset': '07:07 AM',
#      'moon_phase': 'Full Moon',
#      'moon_illumination': 100,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1701064800,
#       'time': '2023-11-27 00:00',
#       'temp_c': 14.8,
#       'temp_f': 58.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 15,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 59,
#       'feelslike_c': 14.7,
#       'feelslike_f': 58.4,
#       'windchill_c': 14.7,
#       'windchill_f': 58.4,
#       'heatindex_c': 14.8,
#       'heatindex_f': 58.6,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.7,
#       'gust_kph': 10.8,
#       'uv': 1.0},
#      {'time_epoch': 1701068400,
#       'time': '2023-11-27 01:00',
#       'temp_c': 14.5,
#       'temp_f': 58.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 73,
#       'feelslike_c': 14.7,
#       'feelslike_f': 58.4,
#       'windchill_c': 14.7,
#       'windchill_f': 58.4,
#       'heatindex_c': 14.5,
#       'heatindex_f': 58.1,
#       'dewpoint_c': 12.3,
#       'dewpoint_f': 54.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.9,
#       'gust_kph': 9.5,
#       'uv': 1.0},
#      {'time_epoch': 1701072000,
#       'time': '2023-11-27 02:00',
#       'temp_c': 14.3,
#       'temp_f': 57.7,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 69,
#       'feelslike_c': 15.0,
#       'feelslike_f': 59.0,
#       'windchill_c': 15.0,
#       'windchill_f': 59.0,
#       'heatindex_c': 14.3,
#       'heatindex_f': 57.7,
#       'dewpoint_c': 12.2,
#       'dewpoint_f': 53.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 1.0},
#      {'time_epoch': 1701075600,
#       'time': '2023-11-27 03:00',
#       'temp_c': 14.1,
#       'temp_f': 57.4,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 18,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 64,
#       'feelslike_c': 14.1,
#       'feelslike_f': 57.4,
#       'windchill_c': 14.1,
#       'windchill_f': 57.4,
#       'heatindex_c': 14.1,
#       'heatindex_f': 57.4,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 1.0},
#      {'time_epoch': 1701079200,
#       'time': '2023-11-27 04:00',
#       'temp_c': 12.6,
#       'temp_f': 54.7,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 12,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 91,
#       'feelslike_c': 12.6,
#       'feelslike_f': 54.7,
#       'windchill_c': 12.6,
#       'windchill_f': 54.7,
#       'heatindex_c': 12.6,
#       'heatindex_f': 54.7,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 1.0},
#      {'time_epoch': 1701082800,
#       'time': '2023-11-27 05:00',
#       'temp_c': 12.5,
#       'temp_f': 54.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 9,
#       'wind_dir': 'N',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 99,
#       'feelslike_c': 13.0,
#       'feelslike_f': 55.4,
#       'windchill_c': 13.0,
#       'windchill_f': 55.4,
#       'heatindex_c': 12.5,
#       'heatindex_f': 54.5,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.1,
#       'gust_kph': 6.6,
#       'uv': 1.0},
#      {'time_epoch': 1701086400,
#       'time': '2023-11-27 06:00',
#       'temp_c': 12.5,
#       'temp_f': 54.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 25,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 98,
#       'feelslike_c': 12.8,
#       'feelslike_f': 55.0,
#       'windchill_c': 12.8,
#       'windchill_f': 55.0,
#       'heatindex_c': 12.5,
#       'heatindex_f': 54.5,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.5,
#       'uv': 1.0},
#      {'time_epoch': 1701090000,
#       'time': '2023-11-27 07:00',
#       'temp_c': 12.7,
#       'temp_f': 54.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 15,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 12.9,
#       'feelslike_f': 55.2,
#       'windchill_c': 12.9,
#       'windchill_f': 55.2,
#       'heatindex_c': 12.7,
#       'heatindex_f': 54.9,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 3.0},
#      {'time_epoch': 1701093600,
#       'time': '2023-11-27 08:00',
#       'temp_c': 12.9,
#       'temp_f': 55.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 13.1,
#       'feelslike_f': 55.6,
#       'windchill_c': 13.1,
#       'windchill_f': 55.6,
#       'heatindex_c': 12.9,
#       'heatindex_f': 55.2,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 3.0},
#      {'time_epoch': 1701097200,
#       'time': '2023-11-27 09:00',
#       'temp_c': 13.1,
#       'temp_f': 55.6,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 19,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 12.9,
#       'feelslike_f': 55.3,
#       'windchill_c': 12.9,
#       'windchill_f': 55.3,
#       'heatindex_c': 13.1,
#       'heatindex_f': 55.6,
#       'dewpoint_c': 10.3,
#       'dewpoint_f': 50.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 3.0},
#      {'time_epoch': 1701100800,
#       'time': '2023-11-27 10:00',
#       'temp_c': 13.7,
#       'temp_f': 56.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 17,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 13.4,
#       'feelslike_f': 56.2,
#       'windchill_c': 13.4,
#       'windchill_f': 56.2,
#       'heatindex_c': 13.7,
#       'heatindex_f': 56.7,
#       'dewpoint_c': 10.7,
#       'dewpoint_f': 51.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 3.0},
#      {'time_epoch': 1701104400,
#       'time': '2023-11-27 11:00',
#       'temp_c': 15.1,
#       'temp_f': 59.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 25,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 100,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.2,
#       'windchill_c': 15.1,
#       'windchill_f': 59.2,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.2,
#       'dewpoint_c': 11.0,
#       'dewpoint_f': 51.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 4.0},
#      {'time_epoch': 1701108000,
#       'time': '2023-11-27 12:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 100,
#       'wind_dir': 'E',
#       'pressure_mb': 1029.0,
#       'pressure_in': 30.39,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 100,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 8.0,
#       'vis_miles': 4.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 4.0},
#      {'time_epoch': 1701111600,
#       'time': '2023-11-27 13:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 20,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 58,
#       'cloud': 94,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'dewpoint_c': 10.2,
#       'dewpoint_f': 50.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.1,
#       'gust_kph': 3.3,
#       'uv': 4.0},
#      {'time_epoch': 1701115200,
#       'time': '2023-11-27 14:00',
#       'temp_c': 19.9,
#       'temp_f': 67.8,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 27,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 53,
#       'cloud': 71,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.8,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.1,
#       'gust_kph': 3.3,
#       'uv': 4.0},
#      {'time_epoch': 1701118800,
#       'time': '2023-11-27 15:00',
#       'temp_c': 21.0,
#       'temp_f': 69.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 80,
#       'wind_dir': 'E',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 41,
#       'feelslike_c': 21.0,
#       'feelslike_f': 69.8,
#       'windchill_c': 21.0,
#       'windchill_f': 69.8,
#       'heatindex_c': 21.0,
#       'heatindex_f': 69.8,
#       'dewpoint_c': 10.3,
#       'dewpoint_f': 50.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 2.1,
#       'gust_kph': 3.3,
#       'uv': 6.0},
#      {'time_epoch': 1701122400,
#       'time': '2023-11-27 16:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 122,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 31,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 10.4,
#       'dewpoint_f': 50.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 6.0},
#      {'time_epoch': 1701126000,
#       'time': '2023-11-27 17:00',
#       'temp_c': 21.0,
#       'temp_f': 69.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 137,
#       'wind_dir': 'SE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 43,
#       'feelslike_c': 21.0,
#       'feelslike_f': 69.8,
#       'windchill_c': 21.0,
#       'windchill_f': 69.8,
#       'heatindex_c': 21.0,
#       'heatindex_f': 69.8,
#       'dewpoint_c': 10.2,
#       'dewpoint_f': 50.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.1,
#       'uv': 6.0},
#      {'time_epoch': 1701129600,
#       'time': '2023-11-27 18:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 146,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 54,
#       'cloud': 47,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 10.5,
#       'dewpoint_f': 50.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.4,
#       'gust_kph': 13.6,
#       'uv': 1.0},
#      {'time_epoch': 1701133200,
#       'time': '2023-11-27 19:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 160,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 100,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.2,
#       'gust_kph': 13.2,
#       'uv': 1.0},
#      {'time_epoch': 1701136800,
#       'time': '2023-11-27 20:00',
#       'temp_c': 16.8,
#       'temp_f': 62.2,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 166,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 100,
#       'feelslike_c': 16.8,
#       'feelslike_f': 62.2,
#       'windchill_c': 16.8,
#       'windchill_f': 62.2,
#       'heatindex_c': 16.8,
#       'heatindex_f': 62.2,
#       'dewpoint_c': 10.7,
#       'dewpoint_f': 51.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 1.0},
#      {'time_epoch': 1701140400,
#       'time': '2023-11-27 21:00',
#       'temp_c': 15.4,
#       'temp_f': 59.7,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 0.7,
#       'wind_kph': 1.1,
#       'wind_degree': 45,
#       'wind_dir': 'NE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 100,
#       'feelslike_c': 15.4,
#       'feelslike_f': 59.7,
#       'windchill_c': 15.4,
#       'windchill_f': 59.7,
#       'heatindex_c': 15.4,
#       'heatindex_f': 59.7,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 0.8,
#       'gust_kph': 1.3,
#       'uv': 1.0},
#      {'time_epoch': 1701144000,
#       'time': '2023-11-27 22:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 1,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.18,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': 13.9,
#       'feelslike_f': 57.0,
#       'windchill_c': 13.9,
#       'windchill_f': 57.0,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.5,
#       'uv': 1.0},
#      {'time_epoch': 1701147600,
#       'time': '2023-11-27 23:00',
#       'temp_c': 14.3,
#       'temp_f': 57.7,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 1,
#       'wind_dir': 'N',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.19,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 13.8,
#       'feelslike_f': 56.8,
#       'windchill_c': 13.8,
#       'windchill_f': 56.8,
#       'heatindex_c': 14.3,
#       'heatindex_f': 57.7,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 1.0}]}]}}

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
response["forecast"]
# Out:
# {'forecastday': [{'date': '2023-11-27',
#    'date_epoch': 1701043200,
#    'day': {'maxtemp_c': 21.5,
#     'maxtemp_f': 70.7,
#     'mintemp_c': 12.5,
#     'mintemp_f': 54.5,
#     'avgtemp_c': 15.9,
#     'avgtemp_f': 60.6,
#     'maxwind_mph': 7.2,
#     'maxwind_kph': 11.5,
#     'totalprecip_mm': 0.0,
#     'totalprecip_in': 0.0,
#     'totalsnow_cm': 0.0,
#     'avgvis_km': 9.8,
#     'avgvis_miles': 6.0,
#     'avghumidity': 73.0,
#     'daily_will_it_rain': 0,
#     'daily_chance_of_rain': 0,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'uv': 4.0},
#    'astro': {'sunrise': '06:52 AM',
#     'sunset': '05:57 PM',
#     'moonrise': '06:15 PM',
#     'moonset': '07:07 AM',
#     'moon_phase': 'Full Moon',
#     'moon_illumination': 100,
#     'is_moon_up': 1,
#     'is_sun_up': 0},
#    'hour': [{'time_epoch': 1701064800,
#      'time': '2023-11-27 00:00',
#      'temp_c': 14.8,
#      'temp_f': 58.6,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 5.8,
#      'wind_kph': 9.4,
#      'wind_degree': 15,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.08,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 84,
#      'cloud': 59,
#      'feelslike_c': 14.7,
#      'feelslike_f': 58.4,
#      'windchill_c': 14.7,
#      'windchill_f': 58.4,
#      'heatindex_c': 14.8,
#      'heatindex_f': 58.6,
#      'dewpoint_c': 12.1,
#      'dewpoint_f': 53.8,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.7,
#      'gust_kph': 10.8,
#      'uv': 1.0},
#     {'time_epoch': 1701068400,
#      'time': '2023-11-27 01:00',
#      'temp_c': 14.5,
#      'temp_f': 58.1,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 5.1,
#      'wind_kph': 8.3,
#      'wind_degree': 8,
#      'wind_dir': 'N',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 86,
#      'cloud': 73,
#      'feelslike_c': 14.7,
#      'feelslike_f': 58.4,
#      'windchill_c': 14.7,
#      'windchill_f': 58.4,
#      'heatindex_c': 14.5,
#      'heatindex_f': 58.1,
#      'dewpoint_c': 12.3,
#      'dewpoint_f': 54.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.9,
#      'gust_kph': 9.5,
#      'uv': 1.0},
#     {'time_epoch': 1701072000,
#      'time': '2023-11-27 02:00',
#      'temp_c': 14.3,
#      'temp_f': 57.7,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 10,
#      'wind_dir': 'N',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 87,
#      'cloud': 69,
#      'feelslike_c': 15.0,
#      'feelslike_f': 59.0,
#      'windchill_c': 15.0,
#      'windchill_f': 59.0,
#      'heatindex_c': 14.3,
#      'heatindex_f': 57.7,
#      'dewpoint_c': 12.2,
#      'dewpoint_f': 53.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.2,
#      'gust_kph': 9.9,
#      'uv': 1.0},
#     {'time_epoch': 1701075600,
#      'time': '2023-11-27 03:00',
#      'temp_c': 14.1,
#      'temp_f': 57.4,
#      'is_day': 0,
#      'condition': {'text': 'Cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#       'code': 1006},
#      'wind_mph': 4.3,
#      'wind_kph': 6.8,
#      'wind_degree': 18,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1018.0,
#      'pressure_in': 30.08,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 86,
#      'cloud': 64,
#      'feelslike_c': 14.1,
#      'feelslike_f': 57.4,
#      'windchill_c': 14.1,
#      'windchill_f': 57.4,
#      'heatindex_c': 14.1,
#      'heatindex_f': 57.4,
#      'dewpoint_c': 11.8,
#      'dewpoint_f': 53.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.9,
#      'gust_kph': 7.9,
#      'uv': 1.0},
#     {'time_epoch': 1701079200,
#      'time': '2023-11-27 04:00',
#      'temp_c': 12.6,
#      'temp_f': 54.7,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 12,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.11,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 82,
#      'cloud': 91,
#      'feelslike_c': 12.6,
#      'feelslike_f': 54.7,
#      'windchill_c': 12.6,
#      'windchill_f': 54.7,
#      'heatindex_c': 12.6,
#      'heatindex_f': 54.7,
#      'dewpoint_c': 9.6,
#      'dewpoint_f': 49.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 1.0},
#     {'time_epoch': 1701082800,
#      'time': '2023-11-27 05:00',
#      'temp_c': 12.5,
#      'temp_f': 54.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 3.6,
#      'wind_kph': 5.8,
#      'wind_degree': 9,
#      'wind_dir': 'N',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.11,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 83,
#      'cloud': 99,
#      'feelslike_c': 13.0,
#      'feelslike_f': 55.4,
#      'windchill_c': 13.0,
#      'windchill_f': 55.4,
#      'heatindex_c': 12.5,
#      'heatindex_f': 54.5,
#      'dewpoint_c': 9.7,
#      'dewpoint_f': 49.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.1,
#      'gust_kph': 6.6,
#      'uv': 1.0},
#     {'time_epoch': 1701086400,
#      'time': '2023-11-27 06:00',
#      'temp_c': 12.5,
#      'temp_f': 54.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 4.0,
#      'wind_kph': 6.5,
#      'wind_degree': 25,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.12,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 83,
#      'cloud': 98,
#      'feelslike_c': 12.8,
#      'feelslike_f': 55.0,
#      'windchill_c': 12.8,
#      'windchill_f': 55.0,
#      'heatindex_c': 12.5,
#      'heatindex_f': 54.5,
#      'dewpoint_c': 9.7,
#      'dewpoint_f': 49.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.6,
#      'gust_kph': 7.5,
#      'uv': 1.0},
#     {'time_epoch': 1701090000,
#      'time': '2023-11-27 07:00',
#      'temp_c': 12.7,
#      'temp_f': 54.9,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 15,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1020.0,
#      'pressure_in': 30.13,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 83,
#      'cloud': 100,
#      'feelslike_c': 12.9,
#      'feelslike_f': 55.2,
#      'windchill_c': 12.9,
#      'windchill_f': 55.2,
#      'heatindex_c': 12.7,
#      'heatindex_f': 54.9,
#      'dewpoint_c': 9.9,
#      'dewpoint_f': 49.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 3.0},
#     {'time_epoch': 1701093600,
#      'time': '2023-11-27 08:00',
#      'temp_c': 12.9,
#      'temp_f': 55.2,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 8,
#      'wind_dir': 'N',
#      'pressure_mb': 1021.0,
#      'pressure_in': 30.15,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 83,
#      'cloud': 100,
#      'feelslike_c': 13.1,
#      'feelslike_f': 55.6,
#      'windchill_c': 13.1,
#      'windchill_f': 55.6,
#      'heatindex_c': 12.9,
#      'heatindex_f': 55.2,
#      'dewpoint_c': 10.1,
#      'dewpoint_f': 50.1,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 3.0},
#     {'time_epoch': 1701097200,
#      'time': '2023-11-27 09:00',
#      'temp_c': 13.1,
#      'temp_f': 55.6,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 19,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1021.0,
#      'pressure_in': 30.16,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 83,
#      'cloud': 100,
#      'feelslike_c': 12.9,
#      'feelslike_f': 55.3,
#      'windchill_c': 12.9,
#      'windchill_f': 55.3,
#      'heatindex_c': 13.1,
#      'heatindex_f': 55.6,
#      'dewpoint_c': 10.3,
#      'dewpoint_f': 50.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 3.0},
#     {'time_epoch': 1701100800,
#      'time': '2023-11-27 10:00',
#      'temp_c': 13.7,
#      'temp_f': 56.7,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 17,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1021.0,
#      'pressure_in': 30.16,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 82,
#      'cloud': 100,
#      'feelslike_c': 13.4,
#      'feelslike_f': 56.2,
#      'windchill_c': 13.4,
#      'windchill_f': 56.2,
#      'heatindex_c': 13.7,
#      'heatindex_f': 56.7,
#      'dewpoint_c': 10.7,
#      'dewpoint_f': 51.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 3.0},
#     {'time_epoch': 1701104400,
#      'time': '2023-11-27 11:00',
#      'temp_c': 15.1,
#      'temp_f': 59.2,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 3.8,
#      'wind_kph': 6.1,
#      'wind_degree': 25,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1021.0,
#      'pressure_in': 30.16,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 76,
#      'cloud': 100,
#      'feelslike_c': 15.1,
#      'feelslike_f': 59.2,
#      'windchill_c': 15.1,
#      'windchill_f': 59.2,
#      'heatindex_c': 15.1,
#      'heatindex_f': 59.2,
#      'dewpoint_c': 11.0,
#      'dewpoint_f': 51.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 4.4,
#      'gust_kph': 7.1,
#      'uv': 4.0},
#     {'time_epoch': 1701108000,
#      'time': '2023-11-27 12:00',
#      'temp_c': 17.0,
#      'temp_f': 62.6,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 6.9,
#      'wind_kph': 11.2,
#      'wind_degree': 100,
#      'wind_dir': 'E',
#      'pressure_mb': 1029.0,
#      'pressure_in': 30.39,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 59,
#      'cloud': 100,
#      'feelslike_c': 16.9,
#      'feelslike_f': 62.4,
#      'windchill_c': 16.9,
#      'windchill_f': 62.4,
#      'heatindex_c': 16.9,
#      'heatindex_f': 62.4,
#      'dewpoint_c': 10.6,
#      'dewpoint_f': 51.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 8.0,
#      'vis_miles': 4.0,
#      'gust_mph': 3.6,
#      'gust_kph': 5.8,
#      'uv': 4.0},
#     {'time_epoch': 1701111600,
#      'time': '2023-11-27 13:00',
#      'temp_c': 18.6,
#      'temp_f': 65.5,
#      'is_day': 1,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#       'code': 1009},
#      'wind_mph': 1.8,
#      'wind_kph': 2.9,
#      'wind_degree': 20,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.08,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 58,
#      'cloud': 94,
#      'feelslike_c': 18.6,
#      'feelslike_f': 65.5,
#      'windchill_c': 18.6,
#      'windchill_f': 65.5,
#      'heatindex_c': 18.6,
#      'heatindex_f': 65.5,
#      'dewpoint_c': 10.2,
#      'dewpoint_f': 50.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 2.1,
#      'gust_kph': 3.3,
#      'uv': 4.0},
#     {'time_epoch': 1701115200,
#      'time': '2023-11-27 14:00',
#      'temp_c': 19.9,
#      'temp_f': 67.8,
#      'is_day': 1,
#      'condition': {'text': 'Cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#       'code': 1006},
#      'wind_mph': 1.8,
#      'wind_kph': 2.9,
#      'wind_degree': 27,
#      'wind_dir': 'NNE',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.04,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 53,
#      'cloud': 71,
#      'feelslike_c': 19.9,
#      'feelslike_f': 67.8,
#      'windchill_c': 19.9,
#      'windchill_f': 67.8,
#      'heatindex_c': 19.9,
#      'heatindex_f': 67.8,
#      'dewpoint_c': 10.1,
#      'dewpoint_f': 50.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 2.1,
#      'gust_kph': 3.3,
#      'uv': 4.0},
#     {'time_epoch': 1701118800,
#      'time': '2023-11-27 15:00',
#      'temp_c': 21.0,
#      'temp_f': 69.8,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 1.8,
#      'wind_kph': 2.9,
#      'wind_degree': 80,
#      'wind_dir': 'E',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.0,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 50,
#      'cloud': 41,
#      'feelslike_c': 21.0,
#      'feelslike_f': 69.8,
#      'windchill_c': 21.0,
#      'windchill_f': 69.8,
#      'heatindex_c': 21.0,
#      'heatindex_f': 69.8,
#      'dewpoint_c': 10.3,
#      'dewpoint_f': 50.5,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 2.1,
#      'gust_kph': 3.3,
#      'uv': 6.0},
#     {'time_epoch': 1701122400,
#      'time': '2023-11-27 16:00',
#      'temp_c': 21.5,
#      'temp_f': 70.7,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 3.4,
#      'wind_kph': 5.4,
#      'wind_degree': 122,
#      'wind_dir': 'ESE',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 49,
#      'cloud': 31,
#      'feelslike_c': 21.5,
#      'feelslike_f': 70.7,
#      'windchill_c': 21.5,
#      'windchill_f': 70.7,
#      'heatindex_c': 24.3,
#      'heatindex_f': 75.7,
#      'dewpoint_c': 10.4,
#      'dewpoint_f': 50.7,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 4.0,
#      'gust_kph': 6.5,
#      'uv': 6.0},
#     {'time_epoch': 1701126000,
#      'time': '2023-11-27 17:00',
#      'temp_c': 21.0,
#      'temp_f': 69.8,
#      'is_day': 1,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'wind_mph': 4.9,
#      'wind_kph': 7.9,
#      'wind_degree': 137,
#      'wind_dir': 'SE',
#      'pressure_mb': 1015.0,
#      'pressure_in': 29.97,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 50,
#      'cloud': 43,
#      'feelslike_c': 21.0,
#      'feelslike_f': 69.8,
#      'windchill_c': 21.0,
#      'windchill_f': 69.8,
#      'heatindex_c': 21.0,
#      'heatindex_f': 69.8,
#      'dewpoint_c': 10.2,
#      'dewpoint_f': 50.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 5.7,
#      'gust_kph': 9.1,
#      'uv': 6.0},
#     {'time_epoch': 1701129600,
#      'time': '2023-11-27 18:00',
#      'temp_c': 20.2,
#      'temp_f': 68.4,
#      'is_day': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#       'code': 1003},
#      'wind_mph': 6.5,
#      'wind_kph': 10.4,
#      'wind_degree': 146,
#      'wind_dir': 'SSE',
#      'pressure_mb': 1016.0,
#      'pressure_in': 30.0,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 54,
#      'cloud': 47,
#      'feelslike_c': 20.2,
#      'feelslike_f': 68.4,
#      'windchill_c': 20.2,
#      'windchill_f': 68.4,
#      'heatindex_c': 20.2,
#      'heatindex_f': 68.4,
#      'dewpoint_c': 10.5,
#      'dewpoint_f': 50.9,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.4,
#      'gust_kph': 13.6,
#      'uv': 1.0},
#     {'time_epoch': 1701133200,
#      'time': '2023-11-27 19:00',
#      'temp_c': 18.6,
#      'temp_f': 65.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 7.2,
#      'wind_kph': 11.5,
#      'wind_degree': 160,
#      'wind_dir': 'SSE',
#      'pressure_mb': 1017.0,
#      'pressure_in': 30.04,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 59,
#      'cloud': 100,
#      'feelslike_c': 18.6,
#      'feelslike_f': 65.5,
#      'windchill_c': 18.6,
#      'windchill_f': 65.5,
#      'heatindex_c': 18.6,
#      'heatindex_f': 65.5,
#      'dewpoint_c': 10.6,
#      'dewpoint_f': 51.0,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 8.2,
#      'gust_kph': 13.2,
#      'uv': 1.0},
#     {'time_epoch': 1701136800,
#      'time': '2023-11-27 20:00',
#      'temp_c': 16.8,
#      'temp_f': 62.2,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 5.4,
#      'wind_kph': 8.6,
#      'wind_degree': 166,
#      'wind_dir': 'SSE',
#      'pressure_mb': 1019.0,
#      'pressure_in': 30.09,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 67,
#      'cloud': 100,
#      'feelslike_c': 16.8,
#      'feelslike_f': 62.2,
#      'windchill_c': 16.8,
#      'windchill_f': 62.2,
#      'heatindex_c': 16.8,
#      'heatindex_f': 62.2,
#      'dewpoint_c': 10.7,
#      'dewpoint_f': 51.3,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 6.2,
#      'gust_kph': 9.9,
#      'uv': 1.0},
#     {'time_epoch': 1701140400,
#      'time': '2023-11-27 21:00',
#      'temp_c': 15.4,
#      'temp_f': 59.7,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 0.7,
#      'wind_kph': 1.1,
#      'wind_degree': 45,
#      'wind_dir': 'NE',
#      'pressure_mb': 1021.0,
#      'pressure_in': 30.15,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 76,
#      'cloud': 100,
#      'feelslike_c': 15.4,
#      'feelslike_f': 59.7,
#      'windchill_c': 15.4,
#      'windchill_f': 59.7,
#      'heatindex_c': 15.4,
#      'heatindex_f': 59.7,
#      'dewpoint_c': 11.2,
#      'dewpoint_f': 52.2,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 0.8,
#      'gust_kph': 1.3,
#      'uv': 1.0},
#     {'time_epoch': 1701144000,
#      'time': '2023-11-27 22:00',
#      'temp_c': 14.7,
#      'temp_f': 58.5,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 4.0,
#      'wind_kph': 6.5,
#      'wind_degree': 1,
#      'wind_dir': 'N',
#      'pressure_mb': 1022.0,
#      'pressure_in': 30.18,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 80,
#      'cloud': 100,
#      'feelslike_c': 13.9,
#      'feelslike_f': 57.0,
#      'windchill_c': 13.9,
#      'windchill_f': 57.0,
#      'heatindex_c': 14.7,
#      'heatindex_f': 58.5,
#      'dewpoint_c': 11.3,
#      'dewpoint_f': 52.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 9.0,
#      'vis_miles': 5.0,
#      'gust_mph': 5.3,
#      'gust_kph': 8.5,
#      'uv': 1.0},
#     {'time_epoch': 1701147600,
#      'time': '2023-11-27 23:00',
#      'temp_c': 14.3,
#      'temp_f': 57.7,
#      'is_day': 0,
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#       'code': 1009},
#      'wind_mph': 6.0,
#      'wind_kph': 9.7,
#      'wind_degree': 1,
#      'wind_dir': 'N',
#      'pressure_mb': 1022.0,
#      'pressure_in': 30.19,
#      'precip_mm': 0.0,
#      'precip_in': 0.0,
#      'humidity': 82,
#      'cloud': 100,
#      'feelslike_c': 13.8,
#      'feelslike_f': 56.8,
#      'windchill_c': 13.8,
#      'windchill_f': 56.8,
#      'heatindex_c': 14.3,
#      'heatindex_f': 57.7,
#      'dewpoint_c': 11.4,
#      'dewpoint_f': 52.4,
#      'will_it_rain': 0,
#      'chance_of_rain': 0,
#      'will_it_snow': 0,
#      'chance_of_snow': 0,
#      'vis_km': 10.0,
#      'vis_miles': 6.0,
#      'gust_mph': 7.5,
#      'gust_kph': 12.1,
#      'uv': 1.0}]}]}

# %%
response["forecast"]["forecastday"][0]
# Out:
# {'date': '2023-11-27',
#  'date_epoch': 1701043200,
#  'day': {'maxtemp_c': 21.5,
#   'maxtemp_f': 70.7,
#   'mintemp_c': 12.5,
#   'mintemp_f': 54.5,
#   'avgtemp_c': 15.9,
#   'avgtemp_f': 60.6,
#   'maxwind_mph': 7.2,
#   'maxwind_kph': 11.5,
#   'totalprecip_mm': 0.0,
#   'totalprecip_in': 0.0,
#   'totalsnow_cm': 0.0,
#   'avgvis_km': 9.8,
#   'avgvis_miles': 6.0,
#   'avghumidity': 73.0,
#   'daily_will_it_rain': 0,
#   'daily_chance_of_rain': 0,
#   'daily_will_it_snow': 0,
#   'daily_chance_of_snow': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'uv': 4.0},
#  'astro': {'sunrise': '06:52 AM',
#   'sunset': '05:57 PM',
#   'moonrise': '06:15 PM',
#   'moonset': '07:07 AM',
#   'moon_phase': 'Full Moon',
#   'moon_illumination': 100,
#   'is_moon_up': 1,
#   'is_sun_up': 0},
#  'hour': [{'time_epoch': 1701064800,
#    'time': '2023-11-27 00:00',
#    'temp_c': 14.8,
#    'temp_f': 58.6,
#    'is_day': 0,
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#     'code': 1003},
#    'wind_mph': 5.8,
#    'wind_kph': 9.4,
#    'wind_degree': 15,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.08,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 84,
#    'cloud': 59,
#    'feelslike_c': 14.7,
#    'feelslike_f': 58.4,
#    'windchill_c': 14.7,
#    'windchill_f': 58.4,
#    'heatindex_c': 14.8,
#    'heatindex_f': 58.6,
#    'dewpoint_c': 12.1,
#    'dewpoint_f': 53.8,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.7,
#    'gust_kph': 10.8,
#    'uv': 1.0},
#   {'time_epoch': 1701068400,
#    'time': '2023-11-27 01:00',
#    'temp_c': 14.5,
#    'temp_f': 58.1,
#    'is_day': 0,
#    'condition': {'text': 'Cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#     'code': 1006},
#    'wind_mph': 5.1,
#    'wind_kph': 8.3,
#    'wind_degree': 8,
#    'wind_dir': 'N',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.09,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 86,
#    'cloud': 73,
#    'feelslike_c': 14.7,
#    'feelslike_f': 58.4,
#    'windchill_c': 14.7,
#    'windchill_f': 58.4,
#    'heatindex_c': 14.5,
#    'heatindex_f': 58.1,
#    'dewpoint_c': 12.3,
#    'dewpoint_f': 54.1,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 5.9,
#    'gust_kph': 9.5,
#    'uv': 1.0},
#   {'time_epoch': 1701072000,
#    'time': '2023-11-27 02:00',
#    'temp_c': 14.3,
#    'temp_f': 57.7,
#    'is_day': 0,
#    'condition': {'text': 'Cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#     'code': 1006},
#    'wind_mph': 5.4,
#    'wind_kph': 8.6,
#    'wind_degree': 10,
#    'wind_dir': 'N',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.09,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 87,
#    'cloud': 69,
#    'feelslike_c': 15.0,
#    'feelslike_f': 59.0,
#    'windchill_c': 15.0,
#    'windchill_f': 59.0,
#    'heatindex_c': 14.3,
#    'heatindex_f': 57.7,
#    'dewpoint_c': 12.2,
#    'dewpoint_f': 53.9,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.2,
#    'gust_kph': 9.9,
#    'uv': 1.0},
#   {'time_epoch': 1701075600,
#    'time': '2023-11-27 03:00',
#    'temp_c': 14.1,
#    'temp_f': 57.4,
#    'is_day': 0,
#    'condition': {'text': 'Cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#     'code': 1006},
#    'wind_mph': 4.3,
#    'wind_kph': 6.8,
#    'wind_degree': 18,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.08,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 86,
#    'cloud': 64,
#    'feelslike_c': 14.1,
#    'feelslike_f': 57.4,
#    'windchill_c': 14.1,
#    'windchill_f': 57.4,
#    'heatindex_c': 14.1,
#    'heatindex_f': 57.4,
#    'dewpoint_c': 11.8,
#    'dewpoint_f': 53.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.9,
#    'gust_kph': 7.9,
#    'uv': 1.0},
#   {'time_epoch': 1701079200,
#    'time': '2023-11-27 04:00',
#    'temp_c': 12.6,
#    'temp_f': 54.7,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 12,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1020.0,
#    'pressure_in': 30.11,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 82,
#    'cloud': 91,
#    'feelslike_c': 12.6,
#    'feelslike_f': 54.7,
#    'windchill_c': 12.6,
#    'windchill_f': 54.7,
#    'heatindex_c': 12.6,
#    'heatindex_f': 54.7,
#    'dewpoint_c': 9.6,
#    'dewpoint_f': 49.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 1.0},
#   {'time_epoch': 1701082800,
#    'time': '2023-11-27 05:00',
#    'temp_c': 12.5,
#    'temp_f': 54.5,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 3.6,
#    'wind_kph': 5.8,
#    'wind_degree': 9,
#    'wind_dir': 'N',
#    'pressure_mb': 1020.0,
#    'pressure_in': 30.11,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 83,
#    'cloud': 99,
#    'feelslike_c': 13.0,
#    'feelslike_f': 55.4,
#    'windchill_c': 13.0,
#    'windchill_f': 55.4,
#    'heatindex_c': 12.5,
#    'heatindex_f': 54.5,
#    'dewpoint_c': 9.7,
#    'dewpoint_f': 49.5,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.1,
#    'gust_kph': 6.6,
#    'uv': 1.0},
#   {'time_epoch': 1701086400,
#    'time': '2023-11-27 06:00',
#    'temp_c': 12.5,
#    'temp_f': 54.5,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 4.0,
#    'wind_kph': 6.5,
#    'wind_degree': 25,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1020.0,
#    'pressure_in': 30.12,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 83,
#    'cloud': 98,
#    'feelslike_c': 12.8,
#    'feelslike_f': 55.0,
#    'windchill_c': 12.8,
#    'windchill_f': 55.0,
#    'heatindex_c': 12.5,
#    'heatindex_f': 54.5,
#    'dewpoint_c': 9.7,
#    'dewpoint_f': 49.5,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.6,
#    'gust_kph': 7.5,
#    'uv': 1.0},
#   {'time_epoch': 1701090000,
#    'time': '2023-11-27 07:00',
#    'temp_c': 12.7,
#    'temp_f': 54.9,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 15,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1020.0,
#    'pressure_in': 30.13,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 83,
#    'cloud': 100,
#    'feelslike_c': 12.9,
#    'feelslike_f': 55.2,
#    'windchill_c': 12.9,
#    'windchill_f': 55.2,
#    'heatindex_c': 12.7,
#    'heatindex_f': 54.9,
#    'dewpoint_c': 9.9,
#    'dewpoint_f': 49.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 3.0},
#   {'time_epoch': 1701093600,
#    'time': '2023-11-27 08:00',
#    'temp_c': 12.9,
#    'temp_f': 55.2,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 8,
#    'wind_dir': 'N',
#    'pressure_mb': 1021.0,
#    'pressure_in': 30.15,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 83,
#    'cloud': 100,
#    'feelslike_c': 13.1,
#    'feelslike_f': 55.6,
#    'windchill_c': 13.1,
#    'windchill_f': 55.6,
#    'heatindex_c': 12.9,
#    'heatindex_f': 55.2,
#    'dewpoint_c': 10.1,
#    'dewpoint_f': 50.1,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 3.0},
#   {'time_epoch': 1701097200,
#    'time': '2023-11-27 09:00',
#    'temp_c': 13.1,
#    'temp_f': 55.6,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 19,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1021.0,
#    'pressure_in': 30.16,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 83,
#    'cloud': 100,
#    'feelslike_c': 12.9,
#    'feelslike_f': 55.3,
#    'windchill_c': 12.9,
#    'windchill_f': 55.3,
#    'heatindex_c': 13.1,
#    'heatindex_f': 55.6,
#    'dewpoint_c': 10.3,
#    'dewpoint_f': 50.5,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 3.0},
#   {'time_epoch': 1701100800,
#    'time': '2023-11-27 10:00',
#    'temp_c': 13.7,
#    'temp_f': 56.7,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 17,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1021.0,
#    'pressure_in': 30.16,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 82,
#    'cloud': 100,
#    'feelslike_c': 13.4,
#    'feelslike_f': 56.2,
#    'windchill_c': 13.4,
#    'windchill_f': 56.2,
#    'heatindex_c': 13.7,
#    'heatindex_f': 56.7,
#    'dewpoint_c': 10.7,
#    'dewpoint_f': 51.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 3.0},
#   {'time_epoch': 1701104400,
#    'time': '2023-11-27 11:00',
#    'temp_c': 15.1,
#    'temp_f': 59.2,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 25,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1021.0,
#    'pressure_in': 30.16,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 76,
#    'cloud': 100,
#    'feelslike_c': 15.1,
#    'feelslike_f': 59.2,
#    'windchill_c': 15.1,
#    'windchill_f': 59.2,
#    'heatindex_c': 15.1,
#    'heatindex_f': 59.2,
#    'dewpoint_c': 11.0,
#    'dewpoint_f': 51.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.1,
#    'uv': 4.0},
#   {'time_epoch': 1701108000,
#    'time': '2023-11-27 12:00',
#    'temp_c': 17.0,
#    'temp_f': 62.6,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 6.9,
#    'wind_kph': 11.2,
#    'wind_degree': 100,
#    'wind_dir': 'E',
#    'pressure_mb': 1029.0,
#    'pressure_in': 30.39,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 59,
#    'cloud': 100,
#    'feelslike_c': 16.9,
#    'feelslike_f': 62.4,
#    'windchill_c': 16.9,
#    'windchill_f': 62.4,
#    'heatindex_c': 16.9,
#    'heatindex_f': 62.4,
#    'dewpoint_c': 10.6,
#    'dewpoint_f': 51.0,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 8.0,
#    'vis_miles': 4.0,
#    'gust_mph': 3.6,
#    'gust_kph': 5.8,
#    'uv': 4.0},
#   {'time_epoch': 1701111600,
#    'time': '2023-11-27 13:00',
#    'temp_c': 18.6,
#    'temp_f': 65.5,
#    'is_day': 1,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 1.8,
#    'wind_kph': 2.9,
#    'wind_degree': 20,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.08,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 58,
#    'cloud': 94,
#    'feelslike_c': 18.6,
#    'feelslike_f': 65.5,
#    'windchill_c': 18.6,
#    'windchill_f': 65.5,
#    'heatindex_c': 18.6,
#    'heatindex_f': 65.5,
#    'dewpoint_c': 10.2,
#    'dewpoint_f': 50.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 2.1,
#    'gust_kph': 3.3,
#    'uv': 4.0},
#   {'time_epoch': 1701115200,
#    'time': '2023-11-27 14:00',
#    'temp_c': 19.9,
#    'temp_f': 67.8,
#    'is_day': 1,
#    'condition': {'text': 'Cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#     'code': 1006},
#    'wind_mph': 1.8,
#    'wind_kph': 2.9,
#    'wind_degree': 27,
#    'wind_dir': 'NNE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.04,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 53,
#    'cloud': 71,
#    'feelslike_c': 19.9,
#    'feelslike_f': 67.8,
#    'windchill_c': 19.9,
#    'windchill_f': 67.8,
#    'heatindex_c': 19.9,
#    'heatindex_f': 67.8,
#    'dewpoint_c': 10.1,
#    'dewpoint_f': 50.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 2.1,
#    'gust_kph': 3.3,
#    'uv': 4.0},
#   {'time_epoch': 1701118800,
#    'time': '2023-11-27 15:00',
#    'temp_c': 21.0,
#    'temp_f': 69.8,
#    'is_day': 1,
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'wind_mph': 1.8,
#    'wind_kph': 2.9,
#    'wind_degree': 80,
#    'wind_dir': 'E',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 50,
#    'cloud': 41,
#    'feelslike_c': 21.0,
#    'feelslike_f': 69.8,
#    'windchill_c': 21.0,
#    'windchill_f': 69.8,
#    'heatindex_c': 21.0,
#    'heatindex_f': 69.8,
#    'dewpoint_c': 10.3,
#    'dewpoint_f': 50.5,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 2.1,
#    'gust_kph': 3.3,
#    'uv': 6.0},
#   {'time_epoch': 1701122400,
#    'time': '2023-11-27 16:00',
#    'temp_c': 21.5,
#    'temp_f': 70.7,
#    'is_day': 1,
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'wind_mph': 3.4,
#    'wind_kph': 5.4,
#    'wind_degree': 122,
#    'wind_dir': 'ESE',
#    'pressure_mb': 1015.0,
#    'pressure_in': 29.97,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 49,
#    'cloud': 31,
#    'feelslike_c': 21.5,
#    'feelslike_f': 70.7,
#    'windchill_c': 21.5,
#    'windchill_f': 70.7,
#    'heatindex_c': 24.3,
#    'heatindex_f': 75.7,
#    'dewpoint_c': 10.4,
#    'dewpoint_f': 50.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 4.0,
#    'gust_kph': 6.5,
#    'uv': 6.0},
#   {'time_epoch': 1701126000,
#    'time': '2023-11-27 17:00',
#    'temp_c': 21.0,
#    'temp_f': 69.8,
#    'is_day': 1,
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'wind_mph': 4.9,
#    'wind_kph': 7.9,
#    'wind_degree': 137,
#    'wind_dir': 'SE',
#    'pressure_mb': 1015.0,
#    'pressure_in': 29.97,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 50,
#    'cloud': 43,
#    'feelslike_c': 21.0,
#    'feelslike_f': 69.8,
#    'windchill_c': 21.0,
#    'windchill_f': 69.8,
#    'heatindex_c': 21.0,
#    'heatindex_f': 69.8,
#    'dewpoint_c': 10.2,
#    'dewpoint_f': 50.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 5.7,
#    'gust_kph': 9.1,
#    'uv': 6.0},
#   {'time_epoch': 1701129600,
#    'time': '2023-11-27 18:00',
#    'temp_c': 20.2,
#    'temp_f': 68.4,
#    'is_day': 0,
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#     'code': 1003},
#    'wind_mph': 6.5,
#    'wind_kph': 10.4,
#    'wind_degree': 146,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 54,
#    'cloud': 47,
#    'feelslike_c': 20.2,
#    'feelslike_f': 68.4,
#    'windchill_c': 20.2,
#    'windchill_f': 68.4,
#    'heatindex_c': 20.2,
#    'heatindex_f': 68.4,
#    'dewpoint_c': 10.5,
#    'dewpoint_f': 50.9,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 8.4,
#    'gust_kph': 13.6,
#    'uv': 1.0},
#   {'time_epoch': 1701133200,
#    'time': '2023-11-27 19:00',
#    'temp_c': 18.6,
#    'temp_f': 65.5,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 7.2,
#    'wind_kph': 11.5,
#    'wind_degree': 160,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.04,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 59,
#    'cloud': 100,
#    'feelslike_c': 18.6,
#    'feelslike_f': 65.5,
#    'windchill_c': 18.6,
#    'windchill_f': 65.5,
#    'heatindex_c': 18.6,
#    'heatindex_f': 65.5,
#    'dewpoint_c': 10.6,
#    'dewpoint_f': 51.0,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 8.2,
#    'gust_kph': 13.2,
#    'uv': 1.0},
#   {'time_epoch': 1701136800,
#    'time': '2023-11-27 20:00',
#    'temp_c': 16.8,
#    'temp_f': 62.2,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 5.4,
#    'wind_kph': 8.6,
#    'wind_degree': 166,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.09,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 67,
#    'cloud': 100,
#    'feelslike_c': 16.8,
#    'feelslike_f': 62.2,
#    'windchill_c': 16.8,
#    'windchill_f': 62.2,
#    'heatindex_c': 16.8,
#    'heatindex_f': 62.2,
#    'dewpoint_c': 10.7,
#    'dewpoint_f': 51.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.2,
#    'gust_kph': 9.9,
#    'uv': 1.0},
#   {'time_epoch': 1701140400,
#    'time': '2023-11-27 21:00',
#    'temp_c': 15.4,
#    'temp_f': 59.7,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 0.7,
#    'wind_kph': 1.1,
#    'wind_degree': 45,
#    'wind_dir': 'NE',
#    'pressure_mb': 1021.0,
#    'pressure_in': 30.15,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 76,
#    'cloud': 100,
#    'feelslike_c': 15.4,
#    'feelslike_f': 59.7,
#    'windchill_c': 15.4,
#    'windchill_f': 59.7,
#    'heatindex_c': 15.4,
#    'heatindex_f': 59.7,
#    'dewpoint_c': 11.2,
#    'dewpoint_f': 52.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 0.8,
#    'gust_kph': 1.3,
#    'uv': 1.0},
#   {'time_epoch': 1701144000,
#    'time': '2023-11-27 22:00',
#    'temp_c': 14.7,
#    'temp_f': 58.5,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 4.0,
#    'wind_kph': 6.5,
#    'wind_degree': 1,
#    'wind_dir': 'N',
#    'pressure_mb': 1022.0,
#    'pressure_in': 30.18,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 80,
#    'cloud': 100,
#    'feelslike_c': 13.9,
#    'feelslike_f': 57.0,
#    'windchill_c': 13.9,
#    'windchill_f': 57.0,
#    'heatindex_c': 14.7,
#    'heatindex_f': 58.5,
#    'dewpoint_c': 11.3,
#    'dewpoint_f': 52.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 5.3,
#    'gust_kph': 8.5,
#    'uv': 1.0},
#   {'time_epoch': 1701147600,
#    'time': '2023-11-27 23:00',
#    'temp_c': 14.3,
#    'temp_f': 57.7,
#    'is_day': 0,
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 6.0,
#    'wind_kph': 9.7,
#    'wind_degree': 1,
#    'wind_dir': 'N',
#    'pressure_mb': 1022.0,
#    'pressure_in': 30.19,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 82,
#    'cloud': 100,
#    'feelslike_c': 13.8,
#    'feelslike_f': 56.8,
#    'windchill_c': 13.8,
#    'windchill_f': 56.8,
#    'heatindex_c': 14.3,
#    'heatindex_f': 57.7,
#    'dewpoint_c': 11.4,
#    'dewpoint_f': 52.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 7.5,
#    'gust_kph': 12.1,
#    'uv': 1.0}]}

# %%
df = pd.json_normalize(response["forecast"]["forecastday"][0])
df
# Out:
#          date  date_epoch                                               hour  \
# 0  2023-11-27  1701043200  [{'time_epoch': 1701064800, 'time': '2023-11-2...
#
#    day.maxtemp_c  day.maxtemp_f  day.mintemp_c  day.mintemp_f  day.avgtemp_c  \
# 0           21.5           70.7           12.5           54.5           15.9
#
#    day.avgtemp_f  day.maxwind_mph  ...  day.condition.code  day.uv  \
# 0           60.6              7.2  ...                1009     4.0
#
#    astro.sunrise  astro.sunset  astro.moonrise  astro.moonset  \
# 0       06:52 AM      05:57 PM        06:15 PM       07:07 AM
#
#    astro.moon_phase  astro.moon_illumination  astro.is_moon_up  \
# 0         Full Moon                      100                 1
#
#    astro.is_sun_up
# 0                0
#
# [1 rows x 33 columns]

# %%
response["forecast"]["forecastday"][0]["hour"][0]['time'].split()
# Out:
# ['2023-11-27', '00:00']

# %% [markdown]
# ## Creando dataframes

# %%
def get_forecast(response, i):
    fecha = response["forecast"]["forecastday"][0]["hour"][i]['time'].split()[0]
    hora = int(response["forecast"]["forecastday"][0]["hour"][i]['time'].split()[1].split(':')[0])
    condicion = response["forecast"]["forecastday"][0]["hour"][i]['condition']['text']
    temperatura = response["forecast"]["forecastday"][0]["hour"][i]['temp_c']
    rain = response["forecast"]["forecastday"][0]["hour"][i]['will_it_rain']
    prob_rain = response["forecast"]["forecastday"][0]["hour"][i]['chance_of_rain']
    
    return fecha, hora, condicion, temperatura, rain, prob_rain

# %%
datos = []

for i in tqdm(range( len(response["forecast"]["forecastday"][0]["hour"])), colour ="purple"):
    datos.append(get_forecast(response, i))
# Out:
# /Users/jibo16/environments/weather_forecast/lib/python3.11/site-packages/tqdm/std.py:161: TqdmWarning: Unknown colour (purple); valid choices: [hex (#00ff00), BLACK, RED, GREEN, YELLOW, BLUE, MAGENTA, CYAN, WHITE]
#   self.colour = colour
# 100%|████████████████████████████████████████| 24/24 [00:00<00:00, 98016.84it/s]

# %%
datos
# Out:
# [('2023-11-27', 0, 'Partly cloudy', 14.8, 0, 0),
#  ('2023-11-27', 1, 'Cloudy', 14.5, 0, 0),
#  ('2023-11-27', 2, 'Cloudy', 14.3, 0, 0),
#  ('2023-11-27', 3, 'Cloudy', 14.1, 0, 0),
#  ('2023-11-27', 4, 'Overcast', 12.6, 0, 0),
#  ('2023-11-27', 5, 'Overcast', 12.5, 0, 0),
#  ('2023-11-27', 6, 'Overcast', 12.5, 0, 0),
#  ('2023-11-27', 7, 'Overcast', 12.7, 0, 0),
#  ('2023-11-27', 8, 'Overcast', 12.9, 0, 0),
#  ('2023-11-27', 9, 'Overcast', 13.1, 0, 0),
#  ('2023-11-27', 10, 'Overcast', 13.7, 0, 0),
#  ('2023-11-27', 11, 'Overcast', 15.1, 0, 0),
#  ('2023-11-27', 12, 'Overcast', 17.0, 0, 0),
#  ('2023-11-27', 13, 'Overcast', 18.6, 0, 0),
#  ('2023-11-27', 14, 'Cloudy', 19.9, 0, 0),
#  ('2023-11-27', 15, 'Partly cloudy', 21.0, 0, 0),
#  ('2023-11-27', 16, 'Partly cloudy', 21.5, 0, 0),
#  ('2023-11-27', 17, 'Partly cloudy', 21.0, 0, 0),
#  ('2023-11-27', 18, 'Partly cloudy', 20.2, 0, 0),
#  ('2023-11-27', 19, 'Overcast', 18.6, 0, 0),
#  ('2023-11-27', 20, 'Overcast', 16.8, 0, 0),
#  ('2023-11-27', 21, 'Overcast', 15.4, 0, 0),
#  ('2023-11-27', 22, 'Overcast', 14.7, 0, 0),
#  ('2023-11-27', 23, 'Overcast', 14.3, 0, 0)]

# %%
cols = ['fecha', 'hora', 'condicion', 'temperatura', 'lluvia', 'prob_lluvia']
df = pd.DataFrame(datos,columns = cols)
df
# Out:
#          fecha  hora      condicion  temperatura  lluvia  prob_lluvia
# 0   2023-11-27     0  Partly cloudy         14.8       0            0
# 1   2023-11-27     1         Cloudy         14.5       0            0
# 2   2023-11-27     2         Cloudy         14.3       0            0
# 3   2023-11-27     3         Cloudy         14.1       0            0
# 4   2023-11-27     4       Overcast         12.6       0            0
# 5   2023-11-27     5       Overcast         12.5       0            0
# 6   2023-11-27     6       Overcast         12.5       0            0
# 7   2023-11-27     7       Overcast         12.7       0            0
# 8   2023-11-27     8       Overcast         12.9       0            0
# 9   2023-11-27     9       Overcast         13.1       0            0
# 10  2023-11-27    10       Overcast         13.7       0            0
# 11  2023-11-27    11       Overcast         15.1       0            0
# 12  2023-11-27    12       Overcast         17.0       0            0
# 13  2023-11-27    13       Overcast         18.6       0            0
# 14  2023-11-27    14         Cloudy         19.9       0            0
# 15  2023-11-27    15  Partly cloudy         21.0       0            0
# 16  2023-11-27    16  Partly cloudy         21.5       0            0
# 17  2023-11-27    17  Partly cloudy         21.0       0            0
# 18  2023-11-27    18  Partly cloudy         20.2       0            0
# 19  2023-11-27    19       Overcast         18.6       0            0
# 20  2023-11-27    20       Overcast         16.8       0            0
# 21  2023-11-27    21       Overcast         15.4       0            0
# 22  2023-11-27    22       Overcast         14.7       0            0
# 23  2023-11-27    23       Overcast         14.3       0            0

# %% [markdown]
# ## Template

# %%
msg = f'\n \n El pronostico del tiempo hoy a las {df["hora"][15]} es de {df["condicion"][15]}'
msg
# Out:
# '\n \n El pronostico del tiempo hoy a las 15 es de Partly cloudy'

# %% [markdown]
# # Mensaje msm por twilio

# %%
time.sleep(2)
account_sid = TWILIO_ACCOUNT_SID
auth_token = TWILIO_AUTH_TOKEN

client = Client(account_sid,auth_token)
message = client.messages \
                .create(
                    body = msg,
                    from_=PHONE_NUMBER,
                    to= P_PHONE
                )
print('Mensaje enviado' + message.sid)
# Out:
# Mensaje enviadoSM06d431f7b61ee2f72835bd531dcbd00a
